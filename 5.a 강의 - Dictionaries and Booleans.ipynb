# %% [markdown]
# # PYTHON PROGRAMMING 기초
# # DICTIONARIES AND BOOLEANS

# %% [markdown]
# # DICTIONARIES

# %% [markdown]
# - my_dict = {'key1':'value1', 'key2':'value2', 'key3':'value3'}
# - 딕쳐너리는 키 밸류의 쌍으로 되어 있다.
# - 키는, 딕셔너리 안에 유일한 값으로 되어 있다. 따라서 키가 같은 값을 가질 수 없다.
#    그러나 밸류는 같은 값이 여러개 있어도 상관없다.
# - 리스트는 인덱스의 오프셋으로 접근하지만, 딕셔너리는 키로 접근한다.

# %% [markdown]
# ## dict : Create

# %%
{}
# Out:
# {}

# %%
dict()
# Out:
# {}

# %%
# 리스트
[ 5, 2, 1, 7, 4 ]
# Out:
# [5, 2, 1, 7, 4]

# %%
# 딕셔너리
{ "키1":"값1", "키2":"값2" , "키3":"값3"}
# Out:
# {'키1': '값1', '키2': '값2', '키3': '값3'}

# %%
# 용어 중요함.
# 키(key) : 딕셔너리 안에 유일한 값으로 되어 있다. 따라서 키가 같은 값을 가질 수 없다.
# 밸류(value) : 키에 대응되는 값. 밸류는 같은 값이 여러개 있어도 상관없다.
# key-value pair : 키와 밸류의 쌍, item 이라고 부름

# %% [markdown]
# ## dict : Read

# %%
my_phone = {"Paul":"010-8236-0635", "mom":"010-9909-0635"}
my_phone
# Out:
# {'Paul': '010-8236-0635', 'mom': '010-9909-0635'}

# %% [markdown]
# [Tip] 리스트 데이터 억세스 : creat, read, update, delete

# %%
# 데이터 억세스
my_phone['Paul']
# Out:
# '010-8236-0635'

# %%
my_phone['mom']
# Out:
# '010-9909-0635'

# %%
# KeyError: 'color' --- IGNORE ---
my_phone['sister']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2408099483.py in <cell line: 0>()
#       1 # KeyError: 'color' --- IGNORE ---
# ----> 2 my_phone['sister']
#
# KeyError: 'sister'

# %%
# 없으면 None 반환 --- IGNORE ---
# Nome : 없는 데이터를 표현하는 데이터 타입
print(type(my_phone.get('sister')))
# Out:
# <class 'NoneType'>

# %% [markdown]
# ## dict : Update

# %%
my_phone = {'브랜드': "Apple", '모델명': "MacBook Pro", '가격': 2000000, '색상': "Silver", 'year': 2020}
my_phone
# Out:
# {'브랜드': 'Apple',
#  '모델명': 'MacBook Pro',
#  '가격': 2000000,
#  '색상': 'Silver',
#  'year': 2020}

# %%
my_phone['가격'] = 2500000
my_phone
# Out:
# {'Paul': '010-8236-0635', 'mom': '010-9909-0635', '가격': 2500000}

# %%
my_phone['생산국가'] = '미국'
my_phone
# Out:
# {'브랜드': 'Apple',
#  '모델명': 'MacBook Pro',
#  '가격': 2000000,
#  '색상': 'Silver',
#  '생산국가': '미국'}

# %% [markdown]
# ## dict : Delete

# %%
del my_phone['year']
my_phone
# Out:
# {'브랜드': 'Apple', '모델명': 'MacBook Pro', '가격': 2000000, '색상': 'Silver'}

# %% [markdown]
# ## dict 객체에서 사용할 수 있는 함수

# %%
#  key 추출
key_list = my_phone.keys()
key_list
# Out:
# dict_keys(['브랜드', '모델명', '가격', '색상', '생산국가'])

# %%
list(key_list)
# Out:
# ['브랜드', '모델명', '가격', '색상', '생산국가']

# %%
#  key 추출한 값을 저장하고 변수는 type이 dict_keys 임.
#  list형으로 쓰고 싶으면 list()로 형변환을 시켜야 함.
key_list = list(key_list)
type(key_list)
# Out:
# list

# %%
# dict의 값(value)만 추출하기
my_phone.values()
# Out:
# dict_values(['Apple', 'MacBook Pro', 2000000, 'Silver', '미국'])

# %%
my_phone.items()
# Out:
# dict_items([('브랜드', 'Apple'), ('모델명', 'MacBook Pro'), ('가격', 2000000), ('색상', 'Silver'), ('생산국가', '미국')])

# %%
list(my_phone.items())
# Out:
# [('브랜드', 'Apple'),
#  ('모델명', 'MacBook Pro'),
#  ('가격', 2000000),
#  ('색상', 'Silver'),
#  ('생산국가', '미국')]

# %%
my_phone
# Out:
# {'브랜드': 'Apple',
#  '모델명': 'MacBook Pro',
#  '가격': 2000000,
#  '색상': 'Silver',
#  '생산국가': '미국'}

# %%
# 여러개의 key에 대해서 한꺼번에 update할 때 사용
my_phone.update({"모델명":"아이패드", "가격":1000000, "색상":"gray"})
my_phone
# Out:
# {'브랜드': 'Apple', '모델명': '아이패드', '가격': 1000000, '색상': 'gray', '생산국가': '미국'}

# %%
# key가 있는지 확인(있으면 True, 없으면 False)
"브랜드" in my_phone.keys()
# "브랜드" in my_phone
# Out:
# True

# %%
"아이패드" in my_phone.keys()
# Out:
# False

# %% [markdown]
# # BOOLEANS
# - Boolean 은 다음 2가지의 오브젝트로 나타낸다. "False" and "True".
# - 숫자 0과 1과 같은 의미이다.

# %%
int(True)
# Out:
# 1

# %%
int(None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4024464104.py in <cell line: 0>()
# ----> 1 int(None)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
