# %% [markdown]
# # <font color='red'> 실습 </font>
# ## <font color='red'> PRINT AND USER INPUT OPERATION </font>

# %% [markdown]
# ### [강의참고 : print 설명 ](https://vision-ai.tistory.com/entry/파이썬-화면-출력-print-함수)

# %% [markdown]
# ### [강의참고 : input 설명 ](  https://vision-ai.tistory.com/entry/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%82%AC%EC%9A%A9%EC%9E%90%EC%97%90%EA%B2%8C-%EC%9E%85%EB%A0%A5%EB%B0%9B%EA%B8%B0-User-Input)

# %% [markdown]
# # <font color='blue'> 1. 유저한테서 KPH값을 입력 받으면, 그에 맞는 MPH로 변환하는 코드를 만드세요. </font>
# - MPH(Miles per Hour) = 0.6214 * KPH
# - KPH(Kilometers per Hour) = 1.6093 * MPH

# %%
# 입력 되는 값은 KMH
kph=input("KMH 값을 입력하세요.>")
# Out:
# KMH 값을 입력하세요.>60

# %%
# kph -> mph
# MPH: 0.6214*KPH
KPH_TO_MPH = 0.6214
mph= int(kph) * KPH_TO_MPH

# %%
# kph -> mph 변환값
mph
# Out:
# 37.284

# %%
# mph -> kph

# %%
# Out:
# 60.0011412

# %% [markdown]
# ## 부동소수점 연산을 정확하게 하려면

# %%
# 정확한 변환 계수 사용
MILE_TO_KM = 1.609344  # 정확한 변환 계수
KM_TO_MILE = 1 / MILE_TO_KM

# %%
KM_TO_MILE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3985170820.py in <cell line: 0>()
# ----> 1 KM_TO_MILE
#
# NameError: name 'KM_TO_MILE' is not defined

# %%
mph = int(kph) * KM_TO_MILE
mph

# %%
mph * MILE_TO_KM
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3095830236.py in <cell line: 0>()
# ----> 1 mph * MILE_TO_KM
#
# NameError: name 'MILE_TO_KM' is not defined

# %% [markdown]
# # <font color='blue'> 2. 유저한테, 년도와 월을 입력받으세요. 그리고나서 해당 년도와 월을 출력하는 코드를 만드세요. (아래 달력과 관련된 코드를 이용하세요.)  </font>
# - import calendar
# - calendar.month(theyear, themonth)¶

# %%
# 프린트 함수를 잘 설명할 수 있는 예제

import calendar

# %%
# 년도와ㅏ 월을 입력 받아서 달력 출력
theyear = 2025
themonth = 9
mon = calendar .month(theyear, themonth)
print(month)
mon
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1533158329.py in <cell line: 0>()
#       2 theyear = 2025
#       3 themonth = 9
# ----> 4 mon = calendar .month(theyear, themonth)
#       5 print(month)
#       6 mon
#
# NameError: name 'calendar' is not defined

# %%
calendar .month(thyear , themonth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2090014543.py in <cell line: 0>()
# ----> 1 calendar .month(thyear , themonth)
#
# NameError: name 'calendar' is not defined

# %% [markdown]
# ### <font color='blue'>3.  유저한테 두개의 float을 입력받아서, 두 수의 곱과 합을, 다음처럼 똑같이 출력하는 코드를 만드세요.</font>
# ## 출력형태 : First is 4.3, and second is 5.21. So, Multiplication = 22.403, addition = 9.51

# %%
first = float(input("첫 번째 숫자를 입력하세요: "))
second = float(input("두 번째 숫자를 입력하세요: "))
# Out:
# 첫 번째 숫자를 입력하세요: 4.3
# 두 번째 숫자를 입력하세요: 5.21

# %%
multiplication = first * second
addition = first + second

# %%
print(f"First is {4.3}, and second is {5.2}. So, Multiplication = {22.403}, addition = {9.51}")

# %% [markdown]
# # 하나의 셀에 코딩하는 방법
