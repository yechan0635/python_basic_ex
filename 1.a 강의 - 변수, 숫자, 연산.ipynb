# %% [markdown]
# # PYTHON PROGRAMMING 기초

# %% [markdown]
# - 파이썬 기본서 : https://wikidocs.net/book/1
# - 파이썬 300제 : https://wikidocs.net/book/922

# %% [markdown]
# ![image.png](data:image/png;base64,...)![datatype.png](attachment:datatype.png)

# %% [markdown]
# # 연산

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 숫자 데이터
# - 정수, 실수가 있음.
# - 연산을 하는 이유?
#     - 매출을 구하고 싶다.
#         - 매출 = 판매수량 * 단가 <- 숫자 연산이 필요함.
#     - 숫자 데이터를 연산하는 것은 데이터를 가공하는 것임.
#
# [숫자 데이터와 연산 예시]
# - 총 클릭수 와 총 노출 수에 대한 데이터가 있다. 이를 가지고 클릭률을 구할 수 있다.
#     - 총 클릭률 = 총 클릭수 / 총 노출수
# - 성장률 계산
#     - 성장률 = (이번달 매출 - 지난달 매출) / 지난달 매출 * 100
# - 데이터 스케일링(머신러닝 데이터 전처리)
#     - 숫자를 0~1 사이 값으로 정규화 하기
#     - 표준 정규 분포로 표준화 하기

# %% [markdown]
# # 사칙연산

# %%
num1=input("숫자1")
num2=input("숫자2")
# Out:
# 숫자120
# 숫자230

# %%
num1
# Out:
# '20'

# %%
num2
# Out:
# '30'

# %%
num1+num2
# Out:
# '2030'

# %%
result=int(num1)+int(num2)

# %%
result
# Out:
# 50

# %%
result/5
# Out:
# 10.0

# %%
num1=int(num1)
num1
# Out:
# 20

# %%
num2=int(num2)
num2
# Out:
# 30

# %%
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1%num2)
print(num1/num2)
print(num1//num2)
print(-num1)
print(abs(num1))
print(num1**num2)
# Out:
# 50
# -10
# 600
# 20
# 0.6666666666666666
# 0
# -20
# 20
# 1073741824000000000000000000000000000000

# %% [markdown]
# # 연산 라이브러리

# %% [markdown]
# - 내장 라이브러리
#   - 파이썬 설치하면 함께 설치됨
#   - 선언없이 사용한 경우:print(), input, abs()
#   - 선언을 해야하는 경우: math, lib, os ,sy
# - 외장 라이브러리
#   - 따로 설치 해야함
#   - pip install numpy

# %%
math

# %%
import math

# %%
del math

# %%
num=10**2
num
# Out:
# 100

# %%
math.sqrt(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2108344649.py in <cell line: 0>()
# ----> 1 math.sqrt
#
# NameError: name 'math' is not defined

# %% [markdown]
# # 연산순서

# %% [markdown]
# ![image.png](attachment:image.png)
# Reference: https://en.wikibooks.org/wiki/Python_Programming/Basic_Math

# %%
# 성장률 = (이번달 매출 - 지난달 매출) / 지난달 매출 * 100

# %% [markdown]
# # 변수 할당
#  - 변수할당은 ( = ) 기호를 사용한다.
#  - 왼족이 변수의 이름이다.
#  - 오른쪽이 변수의 값이다.

# %%
# 메모장을 이용해서 설명
# = 기호는 메모리에 데이터를 저장하는 기호
# = 이 나오면, =의 오른쪽을 =의 왼쪽에 저장하라. 라는 뜻임, 컴퓨터한테 일을 시키는 것임.

# %%
fish = '고등어'  # fish : 고등어
fish
# Out:
# '고등어'

# %%
price = 3000 # price : 3000
price
# Out:
# 3000

# %%
say = "hello"
say
# Out:
# 'hello'

# %%
price * 3 - 1000
# Out:
# 8000

# %%
# 원래 있던 고등어 가격에 2000원이 더 올랐다. 그러면 고등어 4마리는 얼마냐?

# %%
price + 2000
# Out:
# 5000

# %%
price
# Out:
# 3000

# %%
# 변수 Variable : 데이터를 저장하는 메모리 공간의 이름(식별자)

# %% [markdown]
# # 데이터타입을 확인하는 방법
# - type함수를 이용한다.

# %%
fish
# Out:
# '고등어'

# %%
type(fish)
# Out:
# str

# %%
# 함수는
# 문자열이 있고 오른쪽 끝에 소괄로로 시작하고, 끝나면 함수라 하자.
type(price)
# Out:
# int

# %% [markdown]
# # Variable naming rules
# - 변수의 시작은 영문자나 언더스코어(_)로만 시작해야 한다.:
#     - _salary
#     - salary_
# - 변수의 시작 다음에는 숫자나 문자나 언더스코어등 아무거나 와도 상관없다. :
#     - salary1
#     - salary2018x
#     - speed_kph
# - 변수명은, 같은 문자라도 대문자와소문자를 구별하므로, 다른변수로 취급한다.
#     - salary, SALARY
#     - salary, Salary
#     - salary, salarY
#
# - 변수의 시작은 절대 숫자로 시작할수 없다.
# - 다음의 예약어는, 우리가 마음대로 변수로 사용할 수 없는 것들이다.
#
#     ![image.png](attachment:image.png)

# %%
salary = 20 # dollars per hour
Salary = 25
for = 10
saLary = 12
SALARY = 13
s_a_l_a_r_y = 15
2SALARY = 30
_salary = 30
True = 20
salary_ = 33
_SALARY_ = 36

print(salary, Salary, for, saLary, SALARY, s_a_l_a_r_y, 2SALARY, _salary, True, salary_, _SALARY_)

# %% [markdown]
# # 실습

# %% [markdown]
# ## 1. 다음을 실행하면 어떤 결과가 나올까요?

# %%
x = 10
x = 20
x = 15
x
# Out:
# 15

# %%
type(x)
# Out:
# int

# %%
z = x/y

# %%
type(z)

# %% [markdown]
# ## 2. 넓이와 둘레길이를 구하는 코드를 만드세요.
# - a는 11, b는 7일 때의 사갈형의 넓이와 둘레의 길이를 구하세요.

# %%
# 넓이
a = 11
b = 7
a * b
# Out:
# 77

# %%
# 둘레
2*(a+b)
# Out:
# 36

# %% [markdown]
# - 위 값을 넓이와 둘레 변수에 저장하기

# %%
area = a * b
area
# Out:
# 77

# %%
# 둘레
perimeter = 2*(a+b)
perimeter
# Out:
# 36
